# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import numpy as np
import pandas as pd

# %%
pwd()
# Out:
# 'C:\\Users\\Venkatesh K Govindan\\PGP-AIML\\Lab\\Residency-1\\External Session'

# %%
### Read Iris CSV file from current working directory into iris_df dataframe
iris = pd.read_csv("Iris.csv")
iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 120                   6.9                  3.2                   5.7
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# 5                    0.4     Iris-setosa
# 6                    0.3     Iris-setosa
# 7                    0.2     Iris-setosa
# 8                    0.2     Iris-setosa
# 9                    0.1     Iris-setosa
# 10                   0.2     Iris-setosa
# 11                   0.2     Iris-setosa
# 12                   0.1     Iris-setosa
# 13                   0.1     Iris-setosa
# 14                   0.2     Iris-setosa
# 15                   0.4     Iris-setosa
# 16                   0.4     Iris-setosa
# 17                   0.3     Iris-setosa
# 18                   0.3     Iris-setosa
# 19                   0.3     Iris-setosa
# 20                   0.2     Iris-setosa
# 21                   0.4     Iris-setosa
# 22                   0.2     Iris-setosa
# 23                   0.5     Iris-setosa
# 24                   0.2     Iris-setosa
# 25                   0.2     Iris-setosa
# 26                   0.4     Iris-setosa
# 27                   0.2     Iris-setosa
# 28                   0.2     Iris-setosa
# 29                   0.2     Iris-setosa
# ..                   ...             ...
# 120                  2.3  Iris-virginica
# 121                  2.0  Iris-virginica
# 122                  2.0  Iris-virginica
# 123                  1.8  Iris-virginica
# 124                  2.1  Iris-virginica
# 125                  1.8  Iris-virginica
# 126                  1.8  Iris-virginica
# 127                  1.8  Iris-virginica
# 128                  2.1  Iris-virginica
# 129                  1.6  Iris-virginica
# 130                  1.9  Iris-virginica
# 131                  2.0  Iris-virginica
# 132                  2.2  Iris-virginica
# 133                  1.5  Iris-virginica
# 134                  1.4  Iris-virginica
# 135                  2.3  Iris-virginica
# 136                  2.4  Iris-virginica
# 137                  1.8  Iris-virginica
# 138                  1.8  Iris-virginica
# 139                  2.1  Iris-virginica
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
#display information about dataframe
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# Sepal Length (in cm)    150 non-null float64
# Sepal Width in (cm)     150 non-null float64
# Petal length (in cm)    150 non-null float64
# Petal width (in cm)     150 non-null float64
# Class                   150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
#display only column and datatype
iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
#top 10 samples/rows using head()
iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
#top 10 sample/rows using loc
iris.loc[:9]
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
#top 10 sample/rows using iloc
iris.iloc[:10]
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
#bottom 10 sample/rows using tail()
iris.tail(10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %%
#bottom 10 sample/rows using loc
max_cnt=iris.shape[0]
print("Total rows: ", max_cnt)
iris.loc[(max_cnt-10):]
# Out:
# Total rows:  150
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %%
#bottom 10 sample/rows using iloc
iris.iloc[(max_cnt-10):]
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
#shape(rows, columns) of the dataframe
print ("shape of iris dataset is: ", iris.shape)
# Out:
# shape of iris dataset is:  (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
#set first column 'Sepal Length (in cm)' as index
iris_new=iris.set_index('Sepal Length (in cm)')
iris_new.head(10)
# Out:
#                       Sepal Width in (cm)  Petal length (in cm)  \
# Sepal Length (in cm)
# 5.1                                   3.5                   1.4
# 4.9                                   3.0                   1.4
# 4.7                                   3.2                   1.3
# 4.6                                   3.1                   1.5
# 5.0                                   3.6                   1.4
# 5.4                                   3.9                   1.7
# 4.6                                   3.4                   1.4
# 5.0                                   3.4                   1.5
# 4.4                                   2.9                   1.4
# 4.9                                   3.1                   1.5
#
#                       Petal width (in cm)        Class
# Sepal Length (in cm)
# 5.1                                   0.2  Iris-setosa
# 4.9                                   0.2  Iris-setosa
# 4.7                                   0.2  Iris-setosa
# 4.6                                   0.2  Iris-setosa
# 5.0                                   0.2  Iris-setosa
# 5.4                                   0.4  Iris-setosa
# 4.6                                   0.3  Iris-setosa
# 5.0                                   0.2  Iris-setosa
# 4.4                                   0.2  Iris-setosa
# 4.9                                   0.1  Iris-setosa

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
#all rows of 3rd column using iloc function
iris.iloc[:,2]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
#first 10 rows of columns 'Sepal Width' and 'Sepal Length' using column index
iris[['Sepal Width in (cm)', 'Sepal Length (in cm)']].head(10)
# Out:
#    Sepal Width in (cm)  Sepal Length (in cm)
# 0                  3.5                   5.1
# 1                  3.0                   4.9
# 2                  3.2                   4.7
# 3                  3.1                   4.6
# 4                  3.6                   5.0
# 5                  3.9                   5.4
# 6                  3.4                   4.6
# 7                  3.4                   5.0
# 8                  2.9                   4.4
# 9                  3.1                   4.9

# %%
#first 10 rows of columns 'Sepal Length' and 'Sepal Width' using iloc
iris.iloc[:,:2].head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)
# 0                   5.1                  3.5
# 1                   4.9                  3.0
# 2                   4.7                  3.2
# 3                   4.6                  3.1
# 4                   5.0                  3.6
# 5                   5.4                  3.9
# 6                   4.6                  3.4
# 7                   5.0                  3.4
# 8                   4.4                  2.9
# 9                   4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %%
iris[iris.Class=="Iris-setosa"].count()
# Out:
# Sepal Length (in cm)    50
# Sepal Width in (cm)     50
# Petal length (in cm)    50
# Petal width (in cm)     50
# Class                   50
# dtype: int64

# %%
#all columns of row with Class 'Iris-setosa'
iris[iris.Class=="Iris-setosa"]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                    5.1                  3.5                   1.4
# 1                    4.9                  3.0                   1.4
# 2                    4.7                  3.2                   1.3
# 3                    4.6                  3.1                   1.5
# 4                    5.0                  3.6                   1.4
# 5                    5.4                  3.9                   1.7
# 6                    4.6                  3.4                   1.4
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 9                    4.9                  3.1                   1.5
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# 13                   4.3                  3.0                   1.1
# 14                   5.8                  4.0                   1.2
# 15                   5.7                  4.4                   1.5
# 16                   5.4                  3.9                   1.3
# 17                   5.1                  3.5                   1.4
# 18                   5.7                  3.8                   1.7
# 19                   5.1                  3.8                   1.5
# 20                   5.4                  3.4                   1.7
# 21                   5.1                  3.7                   1.5
# 22                   4.6                  3.6                   1.0
# 23                   5.1                  3.3                   1.7
# 24                   4.8                  3.4                   1.9
# 25                   5.0                  3.0                   1.6
# 26                   5.0                  3.4                   1.6
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
# 30                   4.8                  3.1                   1.6
# 31                   5.4                  3.4                   1.5
# 32                   5.2                  4.1                   1.5
# 33                   5.5                  4.2                   1.4
# 34                   4.9                  3.1                   1.5
# 35                   5.0                  3.2                   1.2
# 36                   5.5                  3.5                   1.3
# 37                   4.9                  3.1                   1.5
# 38                   4.4                  3.0                   1.3
# 39                   5.1                  3.4                   1.5
# 40                   5.0                  3.5                   1.3
# 41                   4.5                  2.3                   1.3
# 42                   4.4                  3.2                   1.3
# 43                   5.0                  3.5                   1.6
# 44                   5.1                  3.8                   1.9
# 45                   4.8                  3.0                   1.4
# 46                   5.1                  3.8                   1.6
# 47                   4.6                  3.2                   1.4
# 48                   5.3                  3.7                   1.5
# 49                   5.0                  3.3                   1.4
#
#     Petal width (in cm)        Class
# 0                   0.2  Iris-setosa
# 1                   0.2  Iris-setosa
# 2                   0.2  Iris-setosa
# 3                   0.2  Iris-setosa
# 4                   0.2  Iris-setosa
# 5                   0.4  Iris-setosa
# 6                   0.3  Iris-setosa
# 7                   0.2  Iris-setosa
# 8                   0.2  Iris-setosa
# 9                   0.1  Iris-setosa
# 10                  0.2  Iris-setosa
# 11                  0.2  Iris-setosa
# 12                  0.1  Iris-setosa
# 13                  0.1  Iris-setosa
# 14                  0.2  Iris-setosa
# 15                  0.4  Iris-setosa
# 16                  0.4  Iris-setosa
# 17                  0.3  Iris-setosa
# 18                  0.3  Iris-setosa
# 19                  0.3  Iris-setosa
# 20                  0.2  Iris-setosa
# 21                  0.4  Iris-setosa
# 22                  0.2  Iris-setosa
# 23                  0.5  Iris-setosa
# 24                  0.2  Iris-setosa
# 25                  0.2  Iris-setosa
# 26                  0.4  Iris-setosa
# 27                  0.2  Iris-setosa
# 28                  0.2  Iris-setosa
# 29                  0.2  Iris-setosa
# 30                  0.2  Iris-setosa
# 31                  0.4  Iris-setosa
# 32                  0.1  Iris-setosa
# 33                  0.2  Iris-setosa
# 34                  0.1  Iris-setosa
# 35                  0.2  Iris-setosa
# 36                  0.2  Iris-setosa
# 37                  0.1  Iris-setosa
# 38                  0.2  Iris-setosa
# 39                  0.2  Iris-setosa
# 40                  0.3  Iris-setosa
# 41                  0.3  Iris-setosa
# 42                  0.2  Iris-setosa
# 43                  0.6  Iris-setosa
# 44                  0.4  Iris-setosa
# 45                  0.3  Iris-setosa
# 46                  0.2  Iris-setosa
# 47                  0.2  Iris-setosa
# 48                  0.2  Iris-setosa
# 49                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
iris.rename(columns={"Sepal Length (in cm)": "sepal length", "Sepal Width in (cm)": "sepal width", "Petal length (in cm)": "petal length", "Petal width (in cm)": "petal width"}, inplace=True)
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#multiply 'sepal length' and 'sepal width' and store in new column 'SepalExtra' 
iris['SepalExtra']=iris['sepal length']*iris['sepal width']
iris
# Out:
#      sepal length  sepal width  petal length  petal width           Class  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# 12            4.8          3.0           1.4          0.1     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 15            5.7          4.4           1.5          0.4     Iris-setosa
# 16            5.4          3.9           1.3          0.4     Iris-setosa
# 17            5.1          3.5           1.4          0.3     Iris-setosa
# 18            5.7          3.8           1.7          0.3     Iris-setosa
# 19            5.1          3.8           1.5          0.3     Iris-setosa
# 20            5.4          3.4           1.7          0.2     Iris-setosa
# 21            5.1          3.7           1.5          0.4     Iris-setosa
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 23            5.1          3.3           1.7          0.5     Iris-setosa
# 24            4.8          3.4           1.9          0.2     Iris-setosa
# 25            5.0          3.0           1.6          0.2     Iris-setosa
# 26            5.0          3.4           1.6          0.4     Iris-setosa
# 27            5.2          3.5           1.5          0.2     Iris-setosa
# 28            5.2          3.4           1.4          0.2     Iris-setosa
# 29            4.7          3.2           1.6          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 121           5.6          2.8           4.9          2.0  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 123           6.3          2.7           4.9          1.8  Iris-virginica
# 124           6.7          3.3           5.7          2.1  Iris-virginica
# 125           7.2          3.2           6.0          1.8  Iris-virginica
# 126           6.2          2.8           4.8          1.8  Iris-virginica
# 127           6.1          3.0           4.9          1.8  Iris-virginica
# 128           6.4          2.8           5.6          2.1  Iris-virginica
# 129           7.2          3.0           5.8          1.6  Iris-virginica
# 130           7.4          2.8           6.1          1.9  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 132           6.4          2.8           5.6          2.2  Iris-virginica
# 133           6.3          2.8           5.1          1.5  Iris-virginica
# 134           6.1          2.6           5.6          1.4  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 137           6.4          3.1           5.5          1.8  Iris-virginica
# 138           6.0          3.0           4.8          1.8  Iris-virginica
# 139           6.9          3.1           5.4          2.1  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      SepalExtra
# 0         17.85
# 1         14.70
# 2         15.04
# 3         14.26
# 4         18.00
# 5         21.06
# 6         15.64
# 7         17.00
# 8         12.76
# 9         15.19
# 10        19.98
# 11        16.32
# 12        14.40
# 13        12.90
# 14        23.20
# 15        25.08
# 16        21.06
# 17        17.85
# 18        21.66
# 19        19.38
# 20        18.36
# 21        18.87
# 22        16.56
# 23        16.83
# 24        16.32
# 25        15.00
# 26        17.00
# 27        18.20
# 28        17.68
# 29        15.04
# ..          ...
# 120       22.08
# 121       15.68
# 122       21.56
# 123       17.01
# 124       22.11
# 125       23.04
# 126       17.36
# 127       18.30
# 128       17.92
# 129       21.60
# 130       20.72
# 131       30.02
# 132       17.92
# 133       17.64
# 134       15.86
# 135       23.10
# 136       21.42
# 137       19.84
# 138       18.00
# 139       21.39
# 140       20.77
# 141       21.39
# 142       15.66
# 143       21.76
# 144       22.11
# 145       20.10
# 146       15.75
# 147       19.50
# 148       21.08
# 149       17.70
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
iris.describe()
# Out:
#        sepal length  sepal width  petal length  petal width  SepalExtra
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667   17.806533
# std        0.828066     0.433594      1.764420     0.763161    3.368693
# min        4.300000     2.000000      1.000000     0.100000   10.000000
# 25%        5.100000     2.800000      1.600000     0.300000   15.645000
# 50%        5.800000     3.000000      4.350000     1.300000   17.660000
# 75%        6.400000     3.300000      5.100000     1.800000   20.325000
# max        7.900000     4.400000      6.900000     2.500000   30.020000

# %%
#mean of each column 
iris.mean()
# Out:
# sepal length     5.843333
# sepal width      3.054000
# petal length     3.758667
# petal width      1.198667
# SepalExtra      17.806533
# dtype: float64

# %%
#variance of each column
iris.var()
# Out:
# sepal length     0.685694
# sepal width      0.188004
# petal length     3.113179
# petal width      0.582414
# SepalExtra      11.348090
# dtype: float64

# %%
#variance using std
iris.std()**2
# Out:
# sepal length     0.685694
# sepal width      0.188004
# petal length     3.113179
# petal width      0.582414
# SepalExtra      11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
iris.head(10)
# Out:
#    sepal length  sepal width  petal length  petal width        Class  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa
#
#    SepalExtra
# 0       17.85
# 1       14.70
# 2       15.04
# 3       14.26
# 4       18.00
# 5       21.06
# 6       15.64
# 7       17.00
# 8       12.76
# 9       15.19

# %%
def func1(a,b):
    print("5th row Sepal Length: ", a)
    print ("5th row Sepal Width: ", b)
    return
func1(iris.loc[4,'sepal length'],iris.loc[4,'sepal width'])
# Out:
# 5th row Sepal Length:  5.0
# 5th row Sepal Width:  3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
a=iris.describe()
a
# Out:
#        sepal length  sepal width  petal length  petal width  SepalExtra
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667   17.806533
# std        0.828066     0.433594      1.764420     0.763161    3.368693
# min        4.300000     2.000000      1.000000     0.100000   10.000000
# 25%        5.100000     2.800000      1.600000     0.300000   15.645000
# 50%        5.800000     3.000000      4.350000     1.300000   17.660000
# 75%        6.400000     3.300000      5.100000     1.800000   20.325000
# max        7.900000     4.400000      6.900000     2.500000   30.020000

# %%
#range of all columns in Iris dataset
a.loc['max'] - a.loc['min']
# Out:
# sepal length     3.60
# sepal width      2.40
# petal length     5.90
# petal width      2.40
# SepalExtra      20.02
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
iris.head(10)
# Out:
#    sepal length  sepal width  petal length  petal width        Class  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa
#
#    SepalExtra
# 0       17.85
# 1       14.70
# 2       15.04
# 3       14.26
# 4       18.00
# 5       21.06
# 6       15.64
# 7       17.00
# 8       12.76
# 9       15.19

# %%
iris_sort=iris.sort_values(by=['petal width'],axis=0)
iris_sort
# Out:
#      sepal length  sepal width  petal length  petal width           Class  \
# 32            5.2          4.1           1.5          0.1     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 12            4.8          3.0           1.4          0.1     Iris-setosa
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 27            5.2          3.5           1.5          0.2     Iris-setosa
# 28            5.2          3.4           1.4          0.2     Iris-setosa
# 29            4.7          3.2           1.6          0.2     Iris-setosa
# 30            4.8          3.1           1.6          0.2     Iris-setosa
# 33            5.5          4.2           1.4          0.2     Iris-setosa
# 36            5.5          3.5           1.3          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 39            5.1          3.4           1.5          0.2     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 46            5.1          3.8           1.6          0.2     Iris-setosa
# 47            4.6          3.2           1.4          0.2     Iris-setosa
# 48            5.3          3.7           1.5          0.2     Iris-setosa
# 49            5.0          3.3           1.4          0.2     Iris-setosa
# 25            5.0          3.0           1.6          0.2     Iris-setosa
# 24            4.8          3.4           1.9          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# 121           5.6          2.8           4.9          2.0  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 113           5.7          2.5           5.0          2.0  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 110           6.5          3.2           5.1          2.0  Iris-virginica
# 139           6.9          3.1           5.4          2.1  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 112           6.8          3.0           5.5          2.1  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 124           6.7          3.3           5.7          2.1  Iris-virginica
# 128           6.4          2.8           5.6          2.1  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 132           6.4          2.8           5.6          2.2  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 115           6.4          3.2           5.3          2.3  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
#
#      SepalExtra
# 32        21.32
# 13        12.90
# 37        15.19
# 9         15.19
# 12        14.40
# 34        15.19
# 0         17.85
# 27        18.20
# 28        17.68
# 29        15.04
# 30        14.88
# 33        23.10
# 36        19.25
# 38        13.20
# 39        17.34
# 42        14.08
# 46        19.38
# 47        14.72
# 48        19.61
# 49        16.50
# 25        15.00
# 24        16.32
# 35        16.00
# 3         14.26
# 2         15.04
# 7         17.00
# 8         12.76
# 10        19.98
# 4         18.00
# 11        16.32
# ..          ...
# 111       17.28
# 121       15.68
# 122       21.56
# 147       19.50
# 113       14.25
# 131       30.02
# 110       20.80
# 139       21.39
# 102       21.30
# 112       20.40
# 105       22.80
# 124       22.11
# 128       17.92
# 117       29.26
# 132       17.92
# 104       19.50
# 120       22.08
# 115       20.48
# 148       21.08
# 141       21.39
# 143       21.76
# 145       20.10
# 118       20.02
# 135       23.10
# 136       21.42
# 140       20.77
# 114       16.24
# 100       20.79
# 144       22.11
# 109       25.92
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width        Class  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    SepalExtra
# 0       17.85
# 1       14.70
# 2       15.04
# 3       14.26
# 4       18.00

# %%
iris.drop(columns='SepalExtra',inplace=True)
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
iris.head(10)
# Out:
#    sepal length  sepal width  petal length  petal width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
IrisSubset=iris.iloc[:10,:3]
IrisSubset
# Out:
#    sepal length  sepal width  petal length
# 0           5.1          3.5           1.4
# 1           4.9          3.0           1.4
# 2           4.7          3.2           1.3
# 3           4.6          3.1           1.5
# 4           5.0          3.6           1.4
# 5           5.4          3.9           1.7
# 6           4.6          3.4           1.4
# 7           5.0          3.4           1.5
# 8           4.4          2.9           1.4
# 9           4.9          3.1           1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
hr_ds=pd.read_csv("HR_external.txt",sep='\t')
pd.set_option('display.max_columns', None)
hr_ds.head(10)
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
# 5        Ind6        No   32               2       1005           2
# 6        Ind7        No   59               1       1324           2
# 7        Ind8        No   30               1       1358           2
# 8        Ind9        No   38               2        216           2
# 9       Ind10        No   36               1       1299           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2               1              1               1
# 1                 8          1               1              1               2
# 2                 2          2               6              1               4
# 3                 3          4               1              1               5
# 4                 2          1               2              1               7
# 5                 2          2               1              1               8
# 6                 3          3               2              1              10
# 7                24          1               1              1              11
# 8                23          3               1              1              12
# 9                27          3               2              1              13
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       2          94               3         2
# 1                        3       1          61               2         2
# 2                        4       1          92               2         1
# 3                        4       2          56               3         1
# 4                        1       1          40               3         1
# 5                        4       1          79               3         1
# 6                        3       2          81               4         1
# 7                        4       1          67               3         1
# 8                        4       1          44               2         3
# 9                        3       1          94               3         2
#
#    JobRole  JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0        1                4              1           5993        19479
# 1        2                2              2           5130        24907
# 2        3                3              1           2090         2396
# 3        2                3              2           2909        23159
# 4        3                2              2           3468        16632
# 5        3                4              1           3068        11864
# 6        3                1              2           2670         9964
# 7        3                3              3           2693        13335
# 8        4                3              1           9526         8787
# 9        5                3              2           5237        16577
#
#    NumCompaniesWorked  OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8         1                 11                  3
# 1                   1         2                 23                  4
# 2                   6         1                 15                  3
# 3                   1         1                 11                  3
# 4                   9         2                 12                  3
# 5                   0         2                 13                  3
# 6                   4         1                 20                  4
# 7                   1         2                 22                  4
# 8                   0         2                 21                  4
# 9                   6         2                 13                  3
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
# 5                         3             80                 0
# 6                         1             80                 3
# 7                         2             80                 1
# 8                         2             80                 0
# 9                         2             80                 2
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
# 5                  8                      2                2               7
# 6                 12                      3                2               1
# 7                  1                      2                3               1
# 8                 10                      2                3               9
# 9                 17                      3                2               7
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
# 5                   7                        3                     6
# 6                   0                        0                     0
# 7                   0                        0                     0
# 8                   7                        1                     8
# 9                   7                        7                     7

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
#info() displays dataset details - RangeIndex is # of rows and Data columns is # of columns
hr_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Individual                  1470 non-null object
# Attrition                   1470 non-null object
# Age                         1470 non-null int64
# BusinessTravel              1470 non-null int64
# DailyRate                   1470 non-null int64
# Department                  1470 non-null int64
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null int64
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null int64
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null int64
# JobSatisfaction             1470 non-null int64
# MaritalStatus               1470 non-null int64
# MonthlyIncome               1470 non-null int64
# MonthlyRate                 1470 non-null int64
# NumCompaniesWorked          1470 non-null int64
# OverTime                    1470 non-null int64
# PercentSalaryHike           1470 non-null int64
# PerformanceRating           1470 non-null int64
# RelationshipSatisfaction    1470 non-null int64
# StandardHours               1470 non-null int64
# StockOptionLevel            1470 non-null int64
# TotalWorkingYears           1470 non-null int64
# TrainingTimesLastYear       1470 non-null int64
# WorkLifeBalance             1470 non-null int64
# YearsAtCompany              1470 non-null int64
# YearsInCurrentRole          1470 non-null int64
# YearsSinceLastPromotion     1470 non-null int64
# YearsWithCurrManager        1470 non-null int64
# dtypes: int64(33), object(2)
# memory usage: 402.0+ KB

# %%
# shape of dataframe displays rows and columns
hr_ds.shape
# Out:
# (1470, 35)

# %%
# .index is # of rows and .columns is # of columns
print('# of Rows in HR dataset:', len(hr_ds.index))
print('# of Columns in HR dataset:', len(hr_ds.columns))
# Out:
# # of Rows in HR dataset: 1470
# # of Columns in HR dataset: 35

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
hr_ds.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
hr_ds.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2               1              1               1
# 1                 8          1               1              1               2
# 2                 2          2               6              1               4
# 3                 3          4               1              1               5
# 4                 2          1               2              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       2          94               3         2
# 1                        3       1          61               2         2
# 2                        4       1          92               2         1
# 3                        4       2          56               3         1
# 4                        1       1          40               3         1
#
#    JobRole  JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0        1                4              1           5993        19479
# 1        2                2              2           5130        24907
# 2        3                3              1           2090         2396
# 3        2                3              2           2909        23159
# 4        3                2              2           3468        16632
#
#    NumCompaniesWorked  OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8         1                 11                  3
# 1                   1         2                 23                  4
# 2                   6         1                 15                  3
# 3                   1         1                 11                  3
# 4                   9         2                 12                  3
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2

# %%
# all rows from 3rd column to 10th column
hr_ds.iloc[:,2:10]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# 5      32               2       1005           2                 2          2
# 6      59               1       1324           2                 3          3
# 7      30               1       1358           2                24          1
# 8      38               2        216           2                23          3
# 9      36               1       1299           2                27          3
# 10     35               1        809           2                16          3
# 11     29               1        153           2                15          2
# 12     31               1        670           2                26          1
# 13     34               1       1346           2                19          2
# 14     28               1        103           2                24          3
# 15     29               1       1389           2                21          4
# 16     32               1        334           2                 5          2
# 17     22               3       1123           2                16          2
# 18     53               1       1219           1                 2          4
# 19     38               1        371           2                 2          3
# 20     24               3        673           2                11          2
# 21     36               1       1218           1                 9          4
# 22     34               1        419           2                 7          4
# 23     21               1        391           2                15          2
# 24     34               1        699           2                 6          1
# 25     53               1       1282           2                 5          3
# 26     32               2       1125           2                16          1
# 27     42               1        691           1                 8          4
# 28     44               1        477           2                 7          4
# 29     46               1        705           1                 2          4
# ...   ...             ...        ...         ...               ...        ...
# 1440   36               2        688           2                 4          2
# 1441   56               3        667           2                 1          4
# 1442   29               1       1092           2                 1          4
# 1443   42               1        300           2                 2          3
# 1444   56               1        310           2                 7          2
# 1445   41               1        582           2                28          4
# 1446   34               1        704           1                28          3
# 1447   36               3        301           1                15          4
# 1448   41               1        930           1                 3          3
# 1449   32               1        529           2                 2          3
# 1450   35               1       1146           3                26          4
# 1451   38               1        345           1                10          2
# 1452   50               2        878           1                 1          4
# 1453   36               1       1120           1                11          4
# 1454   45               1        374           1                20          3
# 1455   40               1       1322           2                 2          4
# 1456   35               2       1199           2                18          4
# 1457   40               1       1194           2                 2          4
# 1458   35               1        287           2                 1          4
# 1459   29               1       1378           2                13          2
# 1460   29               1        468           2                28          4
# 1461   50               1        410           1                28          3
# 1462   39               1        722           1                24          1
# 1463   31               3        325           2                 5          3
# 1464   26               1       1167           1                 5          3
# 1465   36               2        884           2                23          2
# 1466   39               1        613           2                 6          1
# 1467   27               1        155           2                 4          3
# 1468   49               2       1023           1                 2          3
# 1469   34               1        628           2                 8          3
#
#       EducationField  EmployeeCount
# 0                  1              1
# 1                  1              1
# 2                  6              1
# 3                  1              1
# 4                  2              1
# 5                  1              1
# 6                  2              1
# 7                  1              1
# 8                  1              1
# 9                  2              1
# 10                 2              1
# 11                 1              1
# 12                 1              1
# 13                 2              1
# 14                 1              1
# 15                 1              1
# 16                 1              1
# 17                 2              1
# 18                 1              1
# 19                 1              1
# 20                 6              1
# 21                 1              1
# 22                 1              1
# 23                 1              1
# 24                 2              1
# 25                 6              1
# 26                 1              1
# 27                 3              1
# 28                 2              1
# 29                 3              1
# ...              ...            ...
# 1440               1              1
# 1441               1              1
# 1442               2              1
# 1443               1              1
# 1444               4              1
# 1445               1              1
# 1446               3              1
# 1447               3              1
# 1448               1              1
# 1449               4              1
# 1450               1              1
# 1451               1              1
# 1452               1              1
# 1453               3              1
# 1454               1              1
# 1455               1              1
# 1456               1              1
# 1457               2              1
# 1458               1              1
# 1459               6              1
# 1460               2              1
# 1461               3              1
# 1462               3              1
# 1463               2              1
# 1464               6              1
# 1465               2              1
# 1466               2              1
# 1467               1              1
# 1468               2              1
# 1469               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
hr_ds.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2               1              1               1
# 1                 8          1               1              1               2
# 2                 2          2               6              1               4
# 3                 3          4               1              1               5
# 4                 2          1               2              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       2          94               3         2
# 1                        3       1          61               2         2
# 2                        4       1          92               2         1
# 3                        4       2          56               3         1
# 4                        1       1          40               3         1
#
#    JobRole  JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0        1                4              1           5993        19479
# 1        2                2              2           5130        24907
# 2        3                3              1           2090         2396
# 3        2                3              2           2909        23159
# 4        3                2              2           3468        16632
#
#    NumCompaniesWorked  OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8         1                 11                  3
# 1                   1         2                 23                  4
# 2                   6         1                 15                  3
# 3                   1         1                 11                  3
# 4                   9         2                 12                  3
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2

# %%
print(hr_ds.Gender.unique())
# Out:
# [2 1]

# %%
#total # of male & female employees 
print("# of male employees in the company: ", hr_ds.Gender[hr_ds.Gender == 1].count())
print("# of female employees in the company: ", hr_ds.Gender[hr_ds.Gender == 2].count())
print("Total # of employees in the company: ", hr_ds.Gender[hr_ds.Gender == 1].count() + hr_ds.Gender[hr_ds.Gender == 2].count())
# Out:
# # of male employees in the company:  882
# # of female employees in the company:  588
# Total # of employees in the company:  1470

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
hr_age=hr_ds.Age.describe()
hr_age
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
# IQR for column Age
print("IQR for column - Age: ", hr_age['75%']-hr_age['25%'])
# Out:
# IQR for column - Age:  13.0

# %%
# IQR for column Age using quantile()
print("IQR for column - Age: ", hr_ds.Age.quantile(.75)-hr_ds.Age.quantile(.25))
# Out:
# IQR for column - Age:  13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
hr_ds.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2               1              1               1
# 1                 8          1               1              1               2
# 2                 2          2               6              1               4
# 3                 3          4               1              1               5
# 4                 2          1               2              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       2          94               3         2
# 1                        3       1          61               2         2
# 2                        4       1          92               2         1
# 3                        4       2          56               3         1
# 4                        1       1          40               3         1
#
#    JobRole  JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0        1                4              1           5993        19479
# 1        2                2              2           5130        24907
# 2        3                3              1           2090         2396
# 3        2                3              2           2909        23159
# 4        3                2              2           3468        16632
#
#    NumCompaniesWorked  OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8         1                 11                  3
# 1                   1         2                 23                  4
# 2                   6         1                 15                  3
# 3                   1         1                 11                  3
# 4                   9         2                 12                  3
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2

# %%
hr_ds.DailyRate.describe()
# Out:
# count    1470.000000
# mean      802.485714
# std       403.509100
# min       102.000000
# 25%       465.000000
# 50%       802.000000
# 75%      1157.000000
# max      1499.000000
# Name: DailyRate, dtype: float64

# %%
print("mean of DailyRate: ", hr_ds.DailyRate.mean())
print("median of DailyRate: ", hr_ds.DailyRate.median())
print("variance of DailyRate: ", hr_ds.DailyRate.var())
# Out:
# mean of DailyRate:  802.4857142857143
# median of DailyRate:  802.0
# variance of DailyRate:  162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# univarient analysis for categorical variable - Attrition_used countplot
sns.countplot(data=hr_ds, x='Attrition')

# %%
# used Gender column as hue in countplot to get count by gender 
sns.countplot(data=hr_ds, x='Attrition', hue='Gender')

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
# univarient analysis for numeric variable - TotalWorkingYear_used boxplot
sns.boxplot(data=hr_ds, x='TotalWorkingYears')

# %%
# frequency distribution mapping for column TotalWorkingYear using Histogram
x=hr_ds.TotalWorkingYears
sns.distplot(x)
